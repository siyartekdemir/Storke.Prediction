# %% [markdown]
# **Importing Librarires**

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Loading The Data**

# %%
df1 = pd.read_csv("healthcare-dataset-stroke-data.csv")
df2 = pd.read_csv("train.csv")

# %%
train_df = pd.merge(df1, df2, on = "id")

# %% [markdown]
# **Analyze the Data and Visualization**

# %%
train_df
# Out:
#          id gender_x  age_x  hypertension_x  heart_disease_x ever_married_x  \
# 0      9046     Male   67.0               0                1            Yes
# 1      1665   Female   79.0               1                0            Yes
# 2     10434   Female   69.0               0                0             No
# 3     12109   Female   81.0               1                0            Yes
# 4     12095   Female   61.0               0                1            Yes
# ...     ...      ...    ...             ...              ...            ...
# 1100   4211     Male   26.0               0                0             No
# 1101   6369     Male   59.0               1                0            Yes
# 1102    579     Male    9.0               0                0             No
# 1103   7293     Male   40.0               0                0            Yes
# 1104  14180   Female   13.0               0                0             No
#
# ...

# %%
train_df.head(5)
# Out:
#       id gender_x  age_x  hypertension_x  heart_disease_x ever_married_x  \
# 0   9046     Male   67.0               0                1            Yes
# 1   1665   Female   79.0               1                0            Yes
# 2  10434   Female   69.0               0                0             No
# 3  12109   Female   81.0               1                0            Yes
# 4  12095   Female   61.0               0                1            Yes
#
#      work_type_x Residence_type_x  avg_glucose_level_x  bmi_x  ... age_y  \
# 0        Private            Urban               228.69   36.6  ...  19.0
# 1  Self-employed            Rural               174.12   24.0  ...  56.0
# 2        Private            Urban                94.39   22.8  ...  16.0
# 3        Private            Rural                80.43   29.7  ...  69.0
# 4       Govt_job            Rural               120.46   36.8  ...  18.0
#
#    hypertension_y heart_disease_y  ever_married_y  work_type_y  \
# ...

# %%
train_df.tail(5)
# Out:
#          id gender_x  age_x  hypertension_x  heart_disease_x ever_married_x  \
# 1100   4211     Male   26.0               0                0             No
# 1101   6369     Male   59.0               1                0            Yes
# 1102    579     Male    9.0               0                0             No
# 1103   7293     Male   40.0               0                0            Yes
# 1104  14180   Female   13.0               0                0             No
#
#      work_type_x Residence_type_x  avg_glucose_level_x  bmi_x  ... age_y  \
# 1100    Govt_job            Rural               100.85   21.0  ...   8.0
# 1101     Private            Rural                95.05   30.9  ...  27.0
# 1102    children            Urban                71.88   17.5  ...  43.0
# 1103     Private            Rural                83.94    NaN  ...  54.0
# 1104    children            Rural               103.08   18.6  ...  41.0
#
#       hypertension_y heart_disease_y  ever_married_y  work_type_y  \
# ...

# %%
train_df.describe
# Out:
# <bound method NDFrame.describe of          id gender_x  age_x  hypertension_x  heart_disease_x ever_married_x  \
# 0      9046     Male   67.0               0                1            Yes
# 1      1665   Female   79.0               1                0            Yes
# 2     10434   Female   69.0               0                0             No
# 3     12109   Female   81.0               1                0            Yes
# 4     12095   Female   61.0               0                1            Yes
# ...     ...      ...    ...             ...              ...            ...
# 1100   4211     Male   26.0               0                0             No
# 1101   6369     Male   59.0               1                0            Yes
# 1102    579     Male    9.0               0                0             No
# 1103   7293     Male   40.0               0                0            Yes
# 1104  14180   Female   13.0               0                0             No
#
# ...

# %%
train_df.isna().sum()
# Out:
# id                      0
# gender_x                0
# age_x                   0
# hypertension_x          0
# heart_disease_x         0
# ever_married_x          0
# work_type_x             0
# Residence_type_x        0
# avg_glucose_level_x     0
# bmi_x                  92
# smoking_status_x        0
# stroke_x                0
# gender_y                0
# age_y                   0
# hypertension_y          0
# heart_disease_y         0
# ever_married_y          0
# work_type_y             0
# Residence_type_y        0
# avg_glucose_level_y     0
# bmi_y                   0
# smoking_status_y        0
# stroke_y                0
# dtype: int64

# %%
train_df.fillna(0)
# Out:
#          id gender_x  age_x  hypertension_x  heart_disease_x ever_married_x  \
# 0      9046     Male   67.0               0                1            Yes
# 1      1665   Female   79.0               1                0            Yes
# 2     10434   Female   69.0               0                0             No
# 3     12109   Female   81.0               1                0            Yes
# 4     12095   Female   61.0               0                1            Yes
# ...     ...      ...    ...             ...              ...            ...
# 1100   4211     Male   26.0               0                0             No
# 1101   6369     Male   59.0               1                0            Yes
# 1102    579     Male    9.0               0                0             No
# 1103   7293     Male   40.0               0                0            Yes
# 1104  14180   Female   13.0               0                0             No
#
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1105 entries, 0 to 1104
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1105 non-null   int64
#  1   gender_x             1105 non-null   object
#  2   age_x                1105 non-null   float64
#  3   hypertension_x       1105 non-null   int64
#  4   heart_disease_x      1105 non-null   int64
#  5   ever_married_x       1105 non-null   object
#  6   work_type_x          1105 non-null   object
#  7   Residence_type_x     1105 non-null   object
#  8   avg_glucose_level_x  1105 non-null   float64
#  9   bmi_x                1013 non-null   float64
#  10  smoking_status_x     1105 non-null   object
#  11  stroke_x             1105 non-null   int64
#  12  gender_y             1105 non-null   object
#  13  age_y                1105 non-null   float64
#  14  hypertension_y       1105 non-null   int64
# ...

# %%
test_df = pd.read_csv("test.csv")

# %%
test_df
# Out:
#           id  gender   age  hypertension  heart_disease ever_married  \
# 0      15304  Female  57.0             0              0          Yes
# 1      15305    Male  70.0             1              0          Yes
# 2      15306  Female   5.0             0              0           No
# 3      15307  Female  56.0             0              0          Yes
# 4      15308    Male  32.0             0              0          Yes
# ...      ...     ...   ...           ...            ...          ...
# 10199  25503  Female  27.0             0              0           No
# 10200  25504    Male  49.0             0              0          Yes
# 10201  25505  Female   3.0             0              0           No
# 10202  25506    Male  31.0             0              0          Yes
# 10203  25507  Female   2.0             0              0           No
#
#       work_type Residence_type  avg_glucose_level   bmi smoking_status
# ...

# %%
test_df.head(5)
# Out:
#       id  gender   age  hypertension  heart_disease ever_married work_type  \
# 0  15304  Female  57.0             0              0          Yes   Private
# 1  15305    Male  70.0             1              0          Yes   Private
# 2  15306  Female   5.0             0              0           No  children
# 3  15307  Female  56.0             0              0          Yes  Govt_job
# 4  15308    Male  32.0             0              0          Yes   Private
#
#   Residence_type  avg_glucose_level   bmi smoking_status
# 0          Rural              82.54  33.4        Unknown
# 1          Urban              72.06  28.5        Unknown
# 2          Urban             103.72  19.5        Unknown
# 3          Urban              69.24  41.4         smokes
# 4          Rural             111.15  30.1         smokes

# %%
test_df.describe
# Out:
# <bound method NDFrame.describe of           id  gender   age  hypertension  heart_disease ever_married  \
# 0      15304  Female  57.0             0              0          Yes
# 1      15305    Male  70.0             1              0          Yes
# 2      15306  Female   5.0             0              0           No
# 3      15307  Female  56.0             0              0          Yes
# 4      15308    Male  32.0             0              0          Yes
# ...      ...     ...   ...           ...            ...          ...
# 10199  25503  Female  27.0             0              0           No
# 10200  25504    Male  49.0             0              0          Yes
# 10201  25505  Female   3.0             0              0           No
# 10202  25506    Male  31.0             0              0          Yes
# 10203  25507  Female   2.0             0              0           No
#
#       work_type Residence_type  avg_glucose_level   bmi smoking_status
# ...

# %%
test_df.isna().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# dtype: int64

# %% [markdown]
# **Preprocessing the Data**

# %%
train_df = train_df[train_df['bmi_x'] > 0] # Remove outliers

# %%
test_df = test_df[test_df['bmi'] > 0]

# %%
train_df = train_df.drop(columns=['id']) # Remove ID column
test_df = test_df.drop(columns=['id'])

# %%
train_df['smoking_status_x'] = train_df['smoking_status_x'].map({'never smoked': 0, 'formerly smoked': 1, 'smokes': 2}) # Transform categorical feature
test_df['smoking_status'] = test_df['smoking_status'].map({'never smoked': 0, 'formerly smoked': 1, 'smokes': 2})

# %%
train_df.head()
# Out:
#   gender_x  age_x  hypertension_x  heart_disease_x ever_married_x  \
# 0     Male   67.0               0                1            Yes
# 1   Female   79.0               1                0            Yes
# 2   Female   69.0               0                0             No
# 3   Female   81.0               1                0            Yes
# 4   Female   61.0               0                1            Yes
#
#      work_type_x Residence_type_x  avg_glucose_level_x  bmi_x  \
# 0        Private            Urban               228.69   36.6
# 1  Self-employed            Rural               174.12   24.0
# 2        Private            Urban                94.39   22.8
# 3        Private            Rural                80.43   29.7
# 4       Govt_job            Rural               120.46   36.8
#
#    smoking_status_x  ...  age_y hypertension_y  heart_disease_y  \
# 0               1.0  ...   19.0              0                0
# ...

# %%
train_df['ever_married_x'] = train_df['ever_married_x'].map({'No': 0, 'Yes': 1})
train_df['Residence_type_x'] = train_df['Residence_type_x'].map({'Urban': 0, 'Rural': 1})
train_df['ever_married_y'] = train_df['ever_married_y'].map({'No': 0, 'Yes': 1})
train_df['Residence_type_y'] = train_df['Residence_type_y'].map({'Urban': 0, 'Rural': 1})
train_df['smoking_status_y'] = train_df['smoking_status_y'].map({'never smoked': 0, 'formerly smoked': 1, 'smokes': 2})

# %%
train_df = train_df.drop(columns = ["work_type_x"])

# %%
train_df = train_df.drop(columns = ["work_type_y"])

# %%
train_df.head(10)
# Out:
#    gender_x  age_x  hypertension_x  heart_disease_x  ever_married_x  \
# 0      Male   67.0               0                1               1
# 1    Female   79.0               1                0               1
# 2    Female   69.0               0                0               0
# 3    Female   81.0               1                0               1
# 4    Female   61.0               0                1               1
# 5    Female   54.0               0                0               1
# 7    Female   79.0               0                1               1
# 8    Female   52.0               1                0               1
# 9      Male   71.0               0                0               1
# 10     Male   48.0               0                0               0
#
#     Residence_type_x  avg_glucose_level_x  bmi_x  smoking_status_x  stroke_x  \
# 0                  0               228.69   36.6               1.0         1
# ...

# %%
train_df["gender_x"] = train_df["gender_x"].map({"Female": 0, "Male": 1})

# %%
train_df["gender_y"] = train_df["gender_y"].map({"Female": 0, "Male": 1})

# %%
train_df.head()
# Out:
#    gender_x  age_x  hypertension_x  heart_disease_x  ever_married_x  \
# 0         1   67.0               0                1               1
# 1         0   79.0               1                0               1
# 2         0   69.0               0                0               0
# 3         0   81.0               1                0               1
# 4         0   61.0               0                1               1
#
#    Residence_type_x  avg_glucose_level_x  bmi_x  smoking_status_x  stroke_x  \
# 0                 0               228.69   36.6               1.0         1
# 1                 1               174.12   24.0               0.0         1
# 2                 0                94.39   22.8               0.0         1
# 3                 1                80.43   29.7               0.0         1
# 4                 1               120.46   36.8               2.0         1
#
#    gender_y  age_y  hypertension_y  heart_disease_y  ever_married_y  \
# ...

# %%
sns.pairplot(train_df)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
sns.heatmap(train_df.corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.scatterplot(x = "age_x", y = "stroke_x", data = train_df)

# Show the plots
plt.show()

# %%
# Create a line plot to visualize the trend of a variable over time
sns.lineplot(x = "age_x", y = "avg_glucose_level_x", data = train_df)

plt.show()

# %%
# Create a histogram to visualize the distribution of a variable
sns.histplot(x = "bmi_x", data = train_df)

plt.show()

# %%
sns.countplot(x = "stroke_x", data = train_df)
plt.title("Distribution of stroke in training dataset")
plt.show()

# %%
test_df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married work_type  \
# 0  Female  57.0             0              0          Yes   Private
# 1    Male  70.0             1              0          Yes   Private
# 2  Female   5.0             0              0           No  children
# 3  Female  56.0             0              0          Yes  Govt_job
# 4    Male  32.0             0              0          Yes   Private
#
#   Residence_type  avg_glucose_level   bmi  smoking_status
# 0          Rural              82.54  33.4             NaN
# 1          Urban              72.06  28.5             NaN
# 2          Urban             103.72  19.5             NaN
# 3          Urban              69.24  41.4             2.0
# 4          Rural             111.15  30.1             2.0

# %%
test_df.fillna(0)
# Out:
#        gender   age  hypertension  heart_disease ever_married work_type  \
# 0      Female  57.0             0              0          Yes   Private
# 1        Male  70.0             1              0          Yes   Private
# 2      Female   5.0             0              0           No  children
# 3      Female  56.0             0              0          Yes  Govt_job
# 4        Male  32.0             0              0          Yes   Private
# ...       ...   ...           ...            ...          ...       ...
# 10199  Female  27.0             0              0           No   Private
# 10200    Male  49.0             0              0          Yes   Private
# 10201  Female   3.0             0              0           No  children
# 10202    Male  31.0             0              0          Yes   Private
# 10203  Female   2.0             0              0           No  children
#
#       Residence_type  avg_glucose_level   bmi  smoking_status
# ...

# %%
test_df["gender"] = test_df["gender"].map({"Female": 0, "Male": 1})

# %%
test_df["Residence_type	"] = test_df["Residence_type"].map({"Urban": 0, "Rural": 1})
test_df["ever_married"] = test_df["ever_married"].map({"No": 0, "Yes": 1})

# %%
test_df = test_df.drop(columns = ["work_type"])

# %% [markdown]
# **Splitting the Data**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train = train_df.drop(['stroke_x'], axis=1)
Y_train = train_df['stroke_x']

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size = 0.3, random_state = 15)

# %%
x_train = pd.DataFrame(x_train)

# %%
#x_train = x_train.dropna()
#y_train = y_train.dropna()

# %%
x_train.shape
# Out:
# (709, 19)

# %%
#x_train = x_train.values.reshape((709, 19))

# %%
#x_train_reshapped = x_train.values.reshape((335, -1))

# %%
y_train.shape
# Out:
# (709,)

# %%
x_train = x_train.fillna(0)

# %%
x_train.shape
# Out:
# (709, 19)

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.svm import SVR, SVC
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier

# %% [markdown]
# **Creating The Models**

# %%
model = SVR()

# %%
model2 = LinearRegression()
model3 = LogisticRegression()
model4 = RandomForestRegressor()

# %%
model5 = SVC(kernel = "linear")
model6 = RandomForestClassifier(n_estimators = 300, criterion = "entropy")

# %%
model.fit(x_train, y_train)
# Out:
# SVR()

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, mean_squared_error, r2_score

# %%
x_test = x_test.fillna(0)

# %%
# Evaluate the model on the testing set
score = model.score(x_test, y_test)

# %%
score
# Out:
# -0.11205195494659992

# %%
score2 = model.score(x_test, y_test)
score3 = model.score(x_test, y_test)
score4 = model.score(x_test, y_test)

# %%
model2.fit(x_train, y_train)
model3.fit(x_train, y_train)
model4.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# RandomForestRegressor()

# %%
model5.fit(x_train, y_train)
model6.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=300)

# %%
print("SVR Score: ", score)
print("LinReg Score: ", score2)
print("LogReg Score: ", score3)
print("RandomForest Score: ", score4)
# Out:
# SVR Score:  -0.11205195494659992
# LinReg Score:  -0.11205195494659992
# LogReg Score:  -0.11205195494659992
# RandomForest Score:  -0.11205195494659992

# %%
y_pred = model.predict(x_test)
y_pred2 = model2.predict(x_test)
y_pred3 = model3.predict(x_test)
y_pred4 = model4.predict(x_test)

# %%
y_pred5 = model5.predict(x_test)
y_pred6 = model6.predict(x_test)

# %%
cm5 = confusion_matrix(y_test, y_pred5)
cm6 = confusion_matrix(y_test, y_pred6)

# %%
acc5 = accuracy_score(y_test, y_pred5)
acc6 = accuracy_score(y_test, y_pred6)

# %%
mse = mean_squared_error(y_test, y_pred)
mse2 = mean_squared_error(y_test, y_pred2)
mse3 = mean_squared_error(y_test, y_pred3)
mse4 = mean_squared_error(y_test, y_pred4)

# %%
print("MSE for SVR: ", mse)
print("MSE for LinReg: ", mse2)
print("MSE for LogReg: ", mse3)
print("MSE for RFR: ", mse4)
# Out:
# MSE for SVR:  0.038782715663877365
# MSE for LinReg:  0.03731654535773581
# MSE for LogReg:  0.046052631578947366
# MSE for RFR:  0.04143519736842105

# %%
# define the MSE values for each model
mse_values = [mse, mse2, mse3, mse4]

# define the labels for each model
model_labels = ['SVR', 'LinReg', 'LogReg', 'RFR']

# create a bar plot
plt.bar(model_labels, mse_values)

# set the plot title and axis labels
plt.title('MSE values for different models')
plt.xlabel('Model')
plt.ylabel('MSE')

# show the plot
plt.show()

# %%
print("Confusion Metrics for SVC: ", cm5)
print("Confusion Metrics for RFC: ", cm6)
# Out:
# Confusion Metrics for SVC:  [[293   0]
#  [ 11   0]]
# Confusion Metrics for RFC:  [[293   0]
#  [ 11   0]]

# %%
sns.heatmap(cm5)
# Out:
# <Axes: >

# %%
sns.heatmap(cm6)
# Out:
# <Axes: >

# %%
print("*************************************")
# Out:
# *************************************

# %%
print("Accuracy Score for SVC: ", acc5)
print("Accuracy Score for RFC: ", acc6)
# Out:
# Accuracy Score for SVC:  0.9638157894736842
# Accuracy Score for RFC:  0.9638157894736842

# %%
# define the MSE values for each model
acc_values = [acc5, acc6]

# define the labels for each model
model_labels = ['SVC', 'RFC']

# create a bar plot
plt.bar(model_labels, acc_values)

# set the plot title and axis labels
plt.title('ACC values for different models')
plt.xlabel('Model')
plt.ylabel('MSE')

# show the plot
plt.show()
